# %%
target_schema = "{['sex', 'births']"
target_examples = "{[['F', 11672], ['M', 0]]}"

source_schema = "{['name', 'sex', 'births']}"
source_examples = "{[['Mary', 'F', 7065], ['Anna', 'F', 2604], ['Emma', 'F', 2003]]}"

# %%
from agent import Agent
agent = Agent(source_schema, target_schema, source_examples, target_examples)

# %%
agent.run()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 agent.run()
#
# File ~/Desktop/projects/cactus/ChatGPTwithSQLscript/react/agent.py:114, in Agent.run(self, to_print, mcts)
#     111         thought = thought_action.strip().split('\n')[0]
#     112         action = gpt4(self.state + f"Thought {i}: {thought}\nAction {i}:", stop=[f"\nObservation {i}:"]).strip()
# --> 114     observation, finish = self.execute_action(action, transformer=self.transformer)
#     115     step_str = f"Thought {i}: {thought}\nAction {i}: {action}\nObservation {i}: {observation}\n"
#     116 self.state += step_str
#
# File ~/Desktop/projects/cactus/ChatGPTwithSQLscript/react/agent.py:48, in Agent.execute_action(self, action, transformer, reason_history)
#      45 # print(f"Executing action: {action}")
#      46 if (action.strip().startswith("TypePredict")):
# ...

# %%
source_schema = "{datetime TEXT, zone_16 NUMERIC}"
target_schema = "{DT_STRATA TEXT, DOW INTEGER, PCT_HOURLY_0100 NUMERIC, PCT_HOURLY_0200 NUMERIC, PCT_HOURLY_0300 NUMERIC, PCT_HOURLY_0400 NUMERIC, PCT_HOURLY_0500 NUMERIC, PCT_HOURLY_0600 NUMERIC, PCT_HOURLY_0700 NUMERIC, PCT_HOURLY_0800 NUMERIC, PCT_HOURLY_0900 NUMERIC, PCT_HOURLY_1000 NUMERIC, PCT_HOURLY_1100 NUMERIC, PCT_HOURLY_1200 NUMERIC, PCT_HOURLY_1300 NUMERIC, PCT_HOURLY_1400 NUMERIC, PCT_HOURLY_1500 NUMERIC, PCT_HOURLY_1600 NUMERIC, PCT_HOURLY_1700 NUMERIC, PCT_HOURLY_1800 NUMERIC, PCT_HOURLY_1900 NUMERIC, PCT_HOURLY_2000 NUMERIC, PCT_HOURLY_2100 NUMERIC, PCT_HOURLY_2200 NUMERIC, PCT_HOURLY_2300 NUMERIC, PCT_HOURLY_2400 NUMERIC, PCT_HOURLY_2500 NUMERIC}"

source_examples = "{1/1/2018 0:00        67.9}"
target_examples = "{10/30/2023    1   1.020 0.960 0.960 0.940 1.000 1.100 1.210 1.230 1.150 1.120 1.160 1.080 1.030 1.030 1.050 1.050 1.080 1.170 1.220 1.370 1.410 1.350 1.220 1.030}"

# %%
from agent import Agent
agent = Agent(source_schema, target_schema, source_examples, target_examples)

# %%
# GET RID OF CLARIFICATIO IN MCTS
agent.run()
# Out:
# Thought 1: Predict the type of the source columns and target columns.
# Action 1:  TypePredict[source_examples, target_examples]
# Observation 1:
# Based on the given examples, the predicted types of the target columns are as follows:
#
# - DT_STRATA: TEXT
# - DOW: INTEGER
# - PCT_HOURLY_0100 to PCT_HOURLY_2500: NUMERIC
#
#
# expanding
# performed actions {'TypePredict'}
# possible actions ['Aggregation', 'DirectMapping']
# Taking action: Aggregation
# random policy
# performed actions {'TypePredict', 'Aggregation'}
# possible actions ['DirectMapping']
# Taking action: DirectMapping
# random policy
# performed actions {'TypePredict', 'Aggregation', 'DirectMapping'}
# possible actions ['Conditional']
# Taking action: Conditional
# random policy
# performed actions {'TypePredict', 'Conditional', 'Aggregation', 'DirectMapping'}
# possible actions ['Finish']
# Taking action: Finish
# Error extracting result: list index out of range
# get reward
# Thought 2: MCTS - Aggregation
# ...

# %%
from agent import Agent
agent = Agent(source_schema, target_schema, source_examples, target_examples)

# %%
from action import *
agent.run()
# Out:
# Thought 1: Predict the type of the source columns and target columns.
# Action 1:  TypePredict[source_examples, target_examples]
# Observation 1:
# In summary, the data types for the target columns are as follows:
#
# - DT_STRATA: TEXT or DATE
# - DOW: INTEGER
# - PCT_HOURLY_0100 to PCT_HOURLY_2500: NUMERIC
#
# Thought 2: Find the direct mapping between the source and target schemas.
# Action 2:  DirectMapping[source_schema, target_schema]
# Observation 2:  After analyzing the source_schema and target_schema, it is clear that there are no direct mappings between the two. The fields in the source_schema do not directly correspond to any fields in the target_schema, both in terms of their names and their data types.
# Thought 3: Identify which target columns are aggregates of source columns.
# Action 3:  Aggregation[source_schema, target_schema]
# Observation 3:
# ...

# %%
from action import *
from agent import Agent
agent = Agent(source_schema, target_schema, source_examples, target_examples)

# %%
agent.run()
# Out:
# Thought 1: Predict the type of the source columns and target columns.
# Action 1:  TypePredict[source_examples, target_examples]
# Observation 1:
# Based on the analysis, the type predictions for the target columns are as follows:
#
# - DT_STRATA: TEXT
# - DOW: INTEGER
# - PCT_HOURLY_0100 to PCT_HOURLY_2500: NUMERIC
#
# expanding
# performed actions {'TypePredict'}
# possible actions ['DirectMapping', 'Aggregation', 'Clarify']
# Taking action: DirectMapping
# random policy
# performed actions {'DirectMapping', 'TypePredict'}
# possible actions ['Aggregation', 'Clarify']
# Taking action: Aggregation
# random policy
# performed actions {'Aggregation', 'DirectMapping', 'TypePredict'}
# possible actions ['Conditional', 'Clarify']
# Taking action: Conditional
# random policy
# performed actions {'Conditional', 'DirectMapping', 'Aggregation', 'TypePredict'}
# possible actions ['Finish', 'Clarify']
# Taking action: Finish
# get reward
# expanding
# performed actions {'TypePredict'}
# ...

# %%
from agent import Agent
agent = Agent(source_schema, target_schema, source_examples, target_examples)
agent.run()
# Out:
# Thought 1: Predict the type of the source columns and target columns.
# Action 1:  TypePredict[source_examples, target_examples]
# Observation 1:
# Based on the analysis of the given target examples, the predicted types of the target columns are as follows:
#
# - DT_STRATA: TEXT
# - DOW: INTEGER
# - PCT_HOURLY_0100 to PCT_HOURLY_2500: NUMERIC
#
#
# expanding
# performed actions {'TypePredict'}
# possible actions ['Clarify', 'Aggregation', 'DirectMapping']
# Taking action: Clarify
# random policy
# performed actions {'TypePredict', 'Clarify'}
# possible actions ['Clarify', 'Aggregation', 'DirectMapping']
# Taking action: Aggregation
# random policy
# performed actions {'TypePredict', 'Clarify', 'Aggregation'}
# possible actions ['Clarify', 'DirectMapping']
# Taking action: DirectMapping
# random policy
# performed actions {'TypePredict', 'Clarify', 'Aggregation', 'DirectMapping'}
# possible actions ['Clarify', 'Conditional']
# Taking action: Conditional
# random policy
# ...
